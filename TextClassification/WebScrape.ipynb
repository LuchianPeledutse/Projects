# %%
import requests
import re
import csv
import time
import random as rd
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
def get_texts_by_read_link(link):
    """
    given the link to the page wehere everything is discussed returns
    a list of texts that represent the discussion, but not yet preprocessed
    """
    #getting html
    main_link = f'https://www.e1.ru/talk/forum/{link}'
    #setting sleep time so that it does not look like an attack
    time.sleep(rd.randint(3,8))
    
    html_response = requests.get(main_link,timeout=30)
    html_soup = BeautifulSoup(html_response.text,'html.parser')
    
    #the text discussions are included in tables
    all_tables = html_soup.find_all('table')
    discussion_tables = [table for table in all_tables if table.find_all('b',string = 'Автор:')]
    
    #getting the texts out of discussions
    the_texts_list = []
    for one_table in discussion_tables:
        the_text = one_table.text
        #start from where the date begins
        from_ = re.search(r'Дата.*\n',the_text).span()[1]
        text_to_save = the_text[from_:]
        the_texts_list.append(text_to_save)

    return the_texts_list

# %%
#checking
res = get_texts_by_read_link('read.php?f=58&i=657840&t=657840')
res
# Out:
# ['            В России большинство, наверно, считают что работает "право сильного" в геополитике: если например Россия побеждает в войне Украину, то это является аргументом, что украинский майдан - дело дохлое. В этой связи хочу напомнить фрагмент фильма "Кин-Дза-Дза":\n\n\n\r\nЭто \n очень актуальная тема: в будущем наверняка будет придумано супероружие, с которым страна, которая нападает первой, всегда выигрывает. Вам не кажется, что человечество должно строго запретить большие войны, наказывать тех кто их начинает, а иначе оно просто не проживёт дольше 300 лет?        \n\n\n\n1/16\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n\n\n\n\n\n                        Re: "Право сильного"\xa0\n                    \n\xa0#657843\xa0\n        \n\nнаверх\n\n\n\n\n\n\n\nАвтор:\xa0AKR_\xa0\xa0\xa0(О пользователе) \nДата:\xa0\xa0\xa011 марта 2024 12:08\n            Поддержу.\r\nСрочно запретите Америку! \r\nИ в Спортлото отпишитесь. \r\nТам входящие регистрируют.        \n\n\n\n16/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n\n\n\n\n\n                        Re: "Право сильного"\xa0\n                    \n\xa0#657846\xa0\n        \n\nнаверх\n\n\n\n\n\n\n\nАвтор:\xa0Alex0815\xa0 \nДата:\xa0\xa0\xa011 марта 2024 12:43\nЦитата:От пользователя:\xa0Peyon\r\nВ России большинство, наверно, считают что работает "право сильного" в геополитике\r\nПраво сильного, в геополитике, работало всегда!\r\nЛишь во времена противостояния США и СССР было какое-никакое равновесие. С развалом СССР это \n равновесие пропало и англосаксы перестали ограничивать себя в применении "права сильного" там, где им это было выгодно.\r\nСейчас англосаксы постепенно, но неумолимо утрачивают это "право сильного", именно поэтому кто-то его должен перехватить...        \n\n\n\n7/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  '            В России большинство, наверно, считают что работает "право сильного" в геополитике: если например Россия побеждает в войне Украину, то это является аргументом, что украинский майдан - дело дохлое. В этой связи хочу напомнить фрагмент фильма "Кин-Дза-Дза":\n\n\n\r\nЭто \n очень актуальная тема: в будущем наверняка будет придумано супероружие, с которым страна, которая нападает первой, всегда выигрывает. Вам не кажется, что человечество должно строго запретить большие войны, наказывать тех кто их начинает, а иначе оно просто не проживёт дольше 300 лет?        \n\n\n\n1/16\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  '            Поддержу.\r\nСрочно запретите Америку! \r\nИ в Спортлото отпишитесь. \r\nТам входящие регистрируют.        \n\n\n\n16/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  'Цитата:От пользователя:\xa0Peyon\r\nВ России большинство, наверно, считают что работает "право сильного" в геополитике',
#  'Цитата:От пользователя:\xa0Peyon\r\nВам не кажется, что человечество должно строго запретить большие войны, наказывать тех кто их начинает, а иначе оно просто не проживёт дольше 300 лет?',
#  'Цитата:От пользователя:\xa0a_murкак автор представляет себе процесс запрещения человечеством больших войн? Ну вот так, чисто технически?',
#  '            очередное проплаченное\r\nну или снежинка        \n\n\n\n6/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  'Цитата:От пользователя:\xa0Peyon\r\nчеловечество должно строго запретить большие войны, наказывать тех кто их начинает',
#  '            z-патриоты, я привык что такие как вы - на своей волне и верите в свои аргументы. Ну ок, а вот вы знаете например, что когда США в 2003 вторглись в Ирак, они не бомбили иракские электростанции? Там писали, что военный эффект от таких бомбёжек минимален, и в то же время это озлобливает местное \n население, поэтому эти бомбёжки нецелесообразны.        \n\n\n\n0/14\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  'Цитата:От пользователя:\xa0Peyon\r\nнапример, что когда США в 2003 вторглись в Ирак, они не бомбили иракские электростанции? Там писали, что военный эффект от таких бомбёжек минимален, и в то же время это озлобливает местное население, поэтому эти бомбёжки нецелесообразны.',
#  'Цитата:От пользователя:\xa0Peyon\r\nони не бомбили иракские электростанции',
#  'Цитата:От пользователя:\xa0Люблю пиво\r\nГуманисты :cen:, так старались сохранить иракскую энергетику, что за время войны и оккупации умертвили от 100т до 1млн иракцев (по разным оценкам)...',
#  'Цитата:От пользователя:\xa0a_mur\r\nникто не отменял. Давай, раз уж ты себя таким мудрым считаешь, объясняй. ',
#  'Цитата:От пользователя:\xa0Peyon\r\nотвечать за это должны американцы?',
#  '            То есть ответов на вопросы не будет. И этот язык в задницу за сунул. Ожидаемо. :-)\r\nОк.\nЦитата:От пользователя:\xa0Peyon\r\nДругое дело, что демократические с авторитарными воюют даже больше, чем авторитарные друг с другом.',
#  'Цитата:От пользователя:\xa0Peyon\r\nНадо разбираться сколько именно',
#  'Цитата:От пользователя:\xa0a_mur\r\nУ меня предложение. Давай всем человечеством запретим демократическим странам воевать с авторитарными.Иначе человечество просто не проживет дольше 300 лет. Как тебе такая идея?',
#  'Цитата:От пользователя:\xa0Peyon\r\nА это не поможет, потому что авторитарные нападают на демократические.',
#  '            чо им, в методичке Оруэлла прописали?\r\nСтопицот раз уже козырнул  :-D \n\r\nя читал, и чо?        \n\n\n\n12/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  '            «Мы слышали, что погибло полмиллиона детей. Это больше, чем погибло в Хиросиме! Стоит ли ваша работа таких результатов?» – спросила у Олбрайт в 1996-м американская журналистка Лесли Шталь в прямом телеэфире. На что будущая госсекретарь ответила: «Это очень тяжёлый выбор, но цена – мы думаем, что она \n того стоила»...        \n\n\n\n13/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  '            Цимес в том, что Оруэлл писал как раз про авторитаризм в самой Великобритании... Но в методичках об этом не скажут. Зачем смущать подаванов?        \n\n\n\n16/0\xa0|\xa0\n\n\xa0\xa0|\xa0\xa0Поделиться:\xa0\xa0\n\n\n',
#  'Цитата:От пользователя:\xa0Alex0815\r\n«Мы слышали, что погибло полмиллиона детей. Это больше, чем погибло в Хиросиме! Стоит ли ваша работа таких результатов?» – спросила у Олбрайт в 1996-м американская журналистка Лесли Шталь в прямом телеэфире. На что будущая госсекретарь ответила: \n «Это очень тяжёлый выбор, но цена – мы думаем, что она того стоила»...',
#  'Цитата:От пользователя:\xa0Peyon\r\nКрасовский',
#  'Цитата:От пользователя:\xa0Peyon\r\n фраза Олбрайт очень неприятная, но если специально такое искать, можно найти самых разных людей которые в разные периоды что-то ляпнули. Вот в России например Красовский ',
#  'Цитата:От пользователя:\xa0Peyon\r\nЯ согласен что фраза Олбрайт очень неприятная',
#  'Цитата:От пользователя:\xa0Lastik\r\nПринципиально иное - допустимость и приемлемость для американской внешней политики убивать полмиллиона детей, сбрасывать ядерную бомбу на города..']

# %%
def get_hrefs(link):
    """
    the function returns a dictionary with keyes read and next
    the read key contains a list with discussion pages and
    the next key contains a link to next page
    """
    #getting parsed html and a tags that contain hrefs
    #same here with time
    time.sleep(rd.randint(2,5))
    
    main_link = requests.get(f'https://www.e1.ru/talk/forum/{link}',timeout=20)
    html_parsed = BeautifulSoup(main_link.text,'html.parser')
    a_tags = html_parsed.find_all('a')
    #creating a dictionary
    main_dict = {'read':[],'next': None}
    #looping
    for one_a in a_tags:
        id_ = one_a.get('id')
        href_ = one_a.get('href')

        if re.match('read',href_):
            main_dict['read'].append(href_)

        if id_ == 'next_page':
            main_dict['next'] = 'list.php' + href_

    return main_dict

# %%
#checking
get_hrefs('list.php?f=58&t=2')
# Out:
# {'read': ['read.php?f=58&i=603228&t=603228',
#   'read.php?f=58&i=575001&t=575001',
#   'read.php?f=58&i=575001&t=575001&page=0',
#   'read.php?f=58&i=575001&t=575001&page=1',
#   'read.php?f=58&i=575001&t=575001&page=2',
#   'read.php?f=58&i=575001&t=575001&page=3',
#   'read.php?f=58&i=575001&t=575001&page=4',
#   'read.php?f=58&i=575001&t=575001&page=5',
#   'read.php?f=58&i=575001&t=575001&page=6',
#   'read.php?f=58&i=572148&t=572148',
#   'read.php?f=58&i=572148&t=572148&page=0',
#   'read.php?f=58&i=572148&t=572148&page=1',
#   'read.php?f=58&i=572148&t=572148&page=2',
#   'read.php?f=58&i=572148&t=572148&page=3',
#   'read.php?f=58&i=572148&t=572148&page=4',
#   'read.php?f=58&i=572148&t=572148&page=14',
#   'read.php?f=58&i=572148&t=572148&page=15',
#   'read.php?f=58&i=572148&t=572148&page=16',
#   'read.php?f=58&i=572148&t=572148&page=17',
#   'read.php?f=58&i=572148&t=572148&page=18',
#   'read.php?f=58&i=546069&t=546069',
#   'read.php?f=58&i=477132&t=477132',
#   'read.php?f=58&i=477132&t=477132&page=0',
#   'read.php?f=58&i=477132&t=477132&page=1',
#   'read.php?f=58&i=477132&t=477132&page=2',
#   'read.php?f=58&i=477132&t=477132&page=3',
#   'read.php?f=58&i=477132&t=477132&page=4',
#   'read.php?f=58&i=477132&t=477132&page=13',
#   'read.php?f=58&i=477132&t=477132&page=14',
#   'read.php?f=58&i=477132&t=477132&page=15',
#   'read.php?f=58&i=477132&t=477132&page=16',
#   'read.php?f=58&i=477132&t=477132&page=17',
#   'read.php?f=58&i=537582&t=537582',
#   'read.php?f=58&i=537582&t=537582&page=0',
#   'read.php?f=58&i=537582&t=537582&page=1',
#   'read.php?f=58&i=537582&t=537582&page=2',
#   'read.php?f=58&i=537582&t=537582&page=3',
#   'read.php?f=58&i=537582&t=537582&page=4',
#   'read.php?f=58&i=537582&t=537582&page=6',
#   'read.php?f=58&i=537582&t=537582&page=7',
#   'read.php?f=58&i=537582&t=537582&page=8',
#   'read.php?f=58&i=537582&t=537582&page=9',
#   'read.php?f=58&i=537582&t=537582&page=10',
#   'read.php?f=58&i=525108&t=525108',
#   'read.php?f=58&i=525108&t=525108&page=0',
#   'read.php?f=58&i=525108&t=525108&page=1',
#   'read.php?f=58&i=559041&t=559041',
#   'read.php?f=58&i=559041&t=559041&page=0',
#   'read.php?f=58&i=559041&t=559041&page=1',
#   'read.php?f=58&i=559041&t=559041&page=2',
#   'read.php?f=58&i=571794&t=571794',
#   'read.php?f=58&i=571794&t=571794&page=0',
#   'read.php?f=58&i=571794&t=571794&page=1',
#   'read.php?f=58&i=379695&t=379695',
#   'read.php?f=58&i=379695&t=379695&page=0',
#   'read.php?f=58&i=379695&t=379695&page=1',
#   'read.php?f=58&i=379695&t=379695&page=2',
#   'read.php?f=58&i=379695&t=379695&page=3',
#   'read.php?f=58&i=379695&t=379695&page=4',
#   'read.php?f=58&i=379401&t=379401',
#   'read.php?f=58&i=379401&t=379401&page=0',
#   'read.php?f=58&i=379401&t=379401&page=1',
#   'read.php?f=58&i=379401&t=379401&page=2',
#   'read.php?f=58&i=379401&t=379401&page=3',
#   'read.php?f=58&i=379401&t=379401&page=4',
#   'read.php?f=58&i=379401&t=379401&page=195',
#   'read.php?f=58&i=379401&t=379401&page=196',
#   'read.php?f=58&i=379401&t=379401&page=197',
#   'read.php?f=58&i=379401&t=379401&page=198',
#   'read.php?f=58&i=379401&t=379401&page=199',
#   'read.php?f=58&i=570930&t=570930',
#   'read.php?f=58&i=570930&t=570930&page=0',
#   'read.php?f=58&i=570930&t=570930&page=1',
#   'read.php?f=58&i=336349&t=336349',
#   'read.php?f=58&i=336349&t=336349&page=0',
#   'read.php?f=58&i=336349&t=336349&page=1',
#   'read.php?f=58&i=336349&t=336349&page=2',
#   'read.php?f=58&i=336349&t=336349&page=3',
#   'read.php?f=58&i=336349&t=336349&page=4',
#   'read.php?f=58&i=336349&t=336349&page=19',
#   'read.php?f=58&i=336349&t=336349&page=20',
#   'read.php?f=58&i=336349&t=336349&page=21',
#   'read.php?f=58&i=336349&t=336349&page=22',
#   'read.php?f=58&i=336349&t=336349&page=23',
#   'read.php?f=58&i=418840&t=418840',
#   'read.php?f=58&i=418840&t=418840&page=0',
#   'read.php?f=58&i=418840&t=418840&page=1',
#   'read.php?f=58&i=418840&t=418840&page=2',
#   'read.php?f=58&i=418840&t=418840&page=3',
#   'read.php?f=58&i=418840&t=418840&page=4',
#   'read.php?f=58&i=418840&t=418840&page=24',
#   'read.php?f=58&i=418840&t=418840&page=25',
#   'read.php?f=58&i=418840&t=418840&page=26',
#   'read.php?f=58&i=418840&t=418840&page=27',
#   'read.php?f=58&i=418840&t=418840&page=28',
#   'read.php?f=58&i=581535&t=581535',
#   'read.php?f=58&i=571509&t=571509',
#   'read.php?f=58&i=571509&t=571509&page=0',
#   'read.php?f=58&i=571509&t=571509&page=1',
#   'read.php?f=58&i=571509&t=571509&page=2',
#   'read.php?f=58&i=471392&t=471392',
#   'read.php?f=58&i=471392&t=471392&page=0',
#   'read.php?f=58&i=471392&t=471392&page=1',
#   'read.php?f=58&i=471392&t=471392&page=2',
#   'read.php?f=58&i=471392&t=471392&page=3',
#   'read.php?f=58&i=471392&t=471392&page=4',
#   'read.php?f=58&i=471392&t=471392&page=12',
#   'read.php?f=58&i=471392&t=471392&page=13',
#   'read.php?f=58&i=471392&t=471392&page=14',
#   'read.php?f=58&i=471392&t=471392&page=15',
#   'read.php?f=58&i=471392&t=471392&page=16',
#   'read.php?f=58&i=535146&t=535146',
#   'read.php?f=58&i=535146&t=535146&page=0',
#   'read.php?f=58&i=535146&t=535146&page=1',
#   'read.php?f=58&i=535146&t=535146&page=2',
#   'read.php?f=58&i=535146&t=535146&page=3',
#   'read.php?f=58&i=535146&t=535146&page=4',
#   'read.php?f=58&i=535146&t=535146&page=406',
#   'read.php?f=58&i=535146&t=535146&page=407',
#   'read.php?f=58&i=535146&t=535146&page=408',
#   'read.php?f=58&i=535146&t=535146&page=409',
#   'read.php?f=58&i=535146&t=535146&page=410',
#   'read.php?f=58&i=361959&t=361959',
#   'read.php?f=58&i=361959&t=361959&page=0',
#   'read.php?f=58&i=361959&t=361959&page=1',
#   'read.php?f=58&i=361959&t=361959&page=2',
#   'read.php?f=58&i=361959&t=361959&page=3',
#   'read.php?f=58&i=361959&t=361959&page=4',
#   'read.php?f=58&i=361959&t=361959&page=8',
#   'read.php?f=58&i=361959&t=361959&page=9',
#   'read.php?f=58&i=361959&t=361959&page=10',
#   'read.php?f=58&i=361959&t=361959&page=11',
#   'read.php?f=58&i=361959&t=361959&page=12',
#   'read.php?f=58&i=503478&t=503478',
#   'read.php?f=58&i=503478&t=503478&page=0',
#   'read.php?f=58&i=503478&t=503478&page=1',
#   'read.php?f=58&i=503478&t=503478&page=2',
#   'read.php?f=58&i=503478&t=503478&page=3',
#   'read.php?f=58&i=503478&t=503478&page=4',
#   'read.php?f=58&i=503478&t=503478&page=401',
#   'read.php?f=58&i=503478&t=503478&page=402',
#   'read.php?f=58&i=503478&t=503478&page=403',
#   'read.php?f=58&i=503478&t=503478&page=404',
#   'read.php?f=58&i=503478&t=503478&page=405',
#   'read.php?f=58&i=460253&t=460253',
#   'read.php?f=58&i=460253&t=460253&page=0',
#   'read.php?f=58&i=460253&t=460253&page=1',
#   'read.php?f=58&i=460253&t=460253&page=2',
#   'read.php?f=58&i=460253&t=460253&page=3',
#   'read.php?f=58&i=460253&t=460253&page=4',
#   'read.php?f=58&i=460253&t=460253&page=8',
#   'read.php?f=58&i=460253&t=460253&page=9',
#   'read.php?f=58&i=460253&t=460253&page=10',
#   'read.php?f=58&i=460253&t=460253&page=11',
#   'read.php?f=58&i=460253&t=460253&page=12',
#   'read.php?f=58&i=543963&t=543963',
#   'read.php?f=58&i=533238&t=533238',
#   'read.php?f=58&i=533238&t=533238&page=0',
#   'read.php?f=58&i=533238&t=533238&page=1',
#   'read.php?f=58&i=533238&t=533238&page=2',
#   'read.php?f=58&i=523104&t=523104',
#   'read.php?f=58&i=507885&t=507885',
#   'read.php?f=58&i=508257&t=508257',
#   'read.php?f=58&i=418462&t=418462',
#   'read.php?f=58&i=418462&t=418462&page=0',
#   'read.php?f=58&i=418462&t=418462&page=1',
#   'read.php?f=58&i=418462&t=418462&page=2',
#   'read.php?f=58&i=418462&t=418462&page=3',
#   'read.php?f=58&i=418462&t=418462&page=4',
#   'read.php?f=58&i=418462&t=418462&page=399',
#   'read.php?f=58&i=418462&t=418462&page=400',
#   'read.php?f=58&i=418462&t=418462&page=401',
#   'read.php?f=58&i=418462&t=418462&page=402',
#   'read.php?f=58&i=418462&t=418462&page=403',
#   'read.php?f=58&i=502143&t=502143',
#   'read.php?f=58&i=460133&t=460133',
#   'read.php?f=58&i=460133&t=460133&page=0',
#   'read.php?f=58&i=460133&t=460133&page=1',
#   'read.php?f=58&i=460133&t=460133&page=2',
#   'read.php?f=58&i=460133&t=460133&page=3',
#   'read.php?f=58&i=460133&t=460133&page=4',
#   'read.php?f=58&i=460133&t=460133&page=11',
#   'read.php?f=58&i=460133&t=460133&page=12',
#   'read.php?f=58&i=460133&t=460133&page=13',
#   'read.php?f=58&i=460133&t=460133&page=14',
#   'read.php?f=58&i=460133&t=460133&page=15',
#   'read.php?f=58&i=499521&t=499521',
#   'read.php?f=58&i=498426&t=498426',
#   'read.php?f=58&i=498015&t=498015',
#   'read.php?f=58&i=472637&t=472637',
#   'read.php?f=58&i=472637&t=472637&page=0',
#   'read.php?f=58&i=472637&t=472637&page=1',
#   'read.php?f=58&i=472637&t=472637&page=2',
#   'read.php?f=58&i=472637&t=472637&page=3',
#   'read.php?f=58&i=464726&t=464726',
#   'read.php?f=58&i=464726&t=464726&page=0',
#   'read.php?f=58&i=464726&t=464726&page=1',
#   'read.php?f=58&i=464726&t=464726&page=2',
#   'read.php?f=58&i=429763&t=429763',
#   'read.php?f=58&i=429763&t=429763&page=0',
#   'read.php?f=58&i=429763&t=429763&page=1',
#   'read.php?f=58&i=429763&t=429763&page=2',
#   'read.php?f=58&i=429763&t=429763&page=3',
#   'read.php?f=58&i=429763&t=429763&page=4',
#   'read.php?f=58&i=429763&t=429763&page=5',
#   'read.php?f=58&i=429763&t=429763&page=6',
#   'read.php?f=58&i=429763&t=429763&page=7',
#   'read.php?f=58&i=478839&t=478839',
#   'read.php?f=58&i=478839&t=478839&page=0',
#   'read.php?f=58&i=477861&t=477861',
#   'read.php?f=58&i=433579&t=433579',
#   'read.php?f=58&i=433579&t=433579&page=0',
#   'read.php?f=58&i=433579&t=433579&page=1',
#   'read.php?f=58&i=433579&t=433579&page=2',
#   'read.php?f=58&i=433579&t=433579&page=3',
#   'read.php?f=58&i=433579&t=433579&page=4',
#   'read.php?f=58&i=433579&t=433579&page=17',
#   'read.php?f=58&i=433579&t=433579&page=18',
#   'read.php?f=58&i=433579&t=433579&page=19',
#   'read.php?f=58&i=433579&t=433579&page=20',
#   'read.php?f=58&i=433579&t=433579&page=21',
#   'read.php?f=58&i=475056&t=475056',
#   'read.php?f=58&i=475056&t=475056&page=0',
#   'read.php?f=58&i=475056&t=475056&page=1',
#   'read.php?f=58&i=443110&t=443110',
#   'read.php?f=58&i=443110&t=443110&page=0',
#   'read.php?f=58&i=443110&t=443110&page=1'],
#  'next': 'list.php?f=58&t=3'}

# %%
def get_classes_with_links():
    """
    return the main classes that we want to analyze along 
    with the links to the first page with themes 
    it is returned in a tuple with elements of the form (class,link_to_first_page)
    """
    #get main page (we know already the link)
    main_html = requests.get('https://www.e1.ru/talk/forum/index.php?f=48')
    soup = BeautifulSoup(main_html.text,'html.parser')

    #get table rows that contain our classes
    list_of_trs = soup.find_all('tr',class_ = 'backgroundLight')
    #get hrefs and class names
    list_of_a = [one_tag.a for one_tag in list_of_trs]
    #getting ready the list to return
    ret_list = [(the_a.text,the_a.get('href')) for the_a in list_of_a]
    return ret_list

# %%
#check the starting point
start = get_classes_with_links()
start
# Out:
# [('Общество', 'list.php?f=60'),
#  ('Растения', 'list.php?f=122'),
#  ('Политика', 'list.php?f=58'),
#  ('Семейные отношения', 'list.php?f=97'),
#  ('Правовые вопросы', 'list.php?f=77'),
#  ('Женский клуб', 'list.php?f=85'),
#  ('Мужской клуб', 'list.php?f=87'),
#  ('Дети и Родители', 'list.php?f=61'),
#  ('Творчество', 'list.php?f=144')]

# %%
#creating a csv file, to which we want to load the data
with open('data.csv','w') as csv_file:
    writer = csv.writer(csv_file,delimiter=';')
    writer.writerow(['Text','Class'])

# %%
def load_texts(path = 'data.csv'):
    """
    The necessary text with their classes to a csv_file
    """
    #setting the limit
    texts_limit = 5556
    #looping through the main classes and their links
    for class_,enter_link in tqdm(start,desc='Getting texts'):
        #needed parameters
        count = 0
        current_link = enter_link
        #adding texts of class until limit
        while count < texts_limit:
            #getting the dict with read and next pages
            path_dict = get_hrefs(current_link)
            #for each link that leads to discussions
            for read_link in path_dict['read']:
                all_texts = get_texts_by_read_link(read_link)
                #open the file to write data to it
                with open(path,'a') as csv_file:
                    writer = csv.writer(csv_file,delimiter=';')
                    #write each particular text data with its class
                    for one_text in all_texts:
                        writer.writerow([one_text,class_])
                        #added one row
                        count += 1
            #move to the next page
            current_link = path_dict['next']

# %%
#getting data
load_texts()
# Out:
# Getting texts: 100%|██████████| 9/9 [6:14:57<00:00, 2499.71s/it]
